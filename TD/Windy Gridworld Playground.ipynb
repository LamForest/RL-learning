# %%
import gym
import numpy as np
import sys

if "../" not in sys.path:
  sys.path.append("../") 

from lib.envs.windy_gridworld import WindyGridworldEnv

# %%
env = WindyGridworldEnv()

print(env.reset())
env.render()

print(env.step(1))
env.render()

print(env.step(1))
env.render()

print(env.step(1))
env.render()

# print(env.step(2))
env.render()

print(env.step(1))
env.render()

print(env.step(1))
env.render()
# Out:
# 30
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# x  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (31, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  x  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (32, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  x  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (33, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  x  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# ...

# %%
print(env.step(1))
env.render()

print(env.step(1))
env.render()

print(env.step(1))
env.render()

# print(env.step(2))
env.render()

print(env.step(1))
env.render()
# Out:
# (6, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  x  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (7, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  x  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (8, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  x  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# o  o  o  o  o  o  o  o  x  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# ...

# %%
print(env.step(2))
env.render()

print(env.step(2))
env.render()
print(env.step(2))
env.render()
print(env.step(2))
env.render()
# Out:
# (19, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  x
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (29, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  x
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (39, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  x
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (49, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  o  x
# o  o  o  o  o  o  o  o  o  o
# ...

# %%
print(env.step(3))
env.render()

print(env.step(3))
env.render()
# Out:
# (48, -1.0, False, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  T  o  o
# o  o  o  o  o  o  o  o  x  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
#
# (37, -1.0, True, {'prob': 1.0})
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  x  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o
